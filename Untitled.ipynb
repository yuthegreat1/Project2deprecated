# %%
import requests

url = "https://tasty.p.rapidapi.com/recipes/list"

querystring = {"from":"0","size":"20","tags":"under_30_minutes","q":"chicken"}

headers = {
	"X-RapidAPI-Key": "0b7d6a8452msh71d37d1067e58bfp1bada4jsn702a564d2a76",
	"X-RapidAPI-Host": "tasty.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"count":27,"results":[{"country":"US","user_ratings":{"count_positive":3,"score":0.375,"count_negative":5},"compilations":[],"tips_and_ratings_enabled":true,"video_url":null,"original_video_url":null,"promotion":"full","facebook_posts":[],"id":8354,"description":"These healthy-ish, plant-based mushroom nuggets will be the hype of your next get-together. This easy snack is crispy, crunchy, and savory and pairs well with almost any dipping sauce.","inspired_by_url":null,"thumbnail_url":"https://img.buzzfeed.com/tasty-app-user-assets-prod-us-east-1/recipes/49c3356ce3394ca9aec09bd7162a49b2.jpeg","topics":[{"slug":"best-vegetarian","name":"Best Vegetarian"},{"name":"Romantic Dinners","slug":"romantic-dinners"},{"slug":"vegan","name":"Vegan"},{"name":"Snacks","slug":"snacks"}],"num_servings":4,"show":{"name":"Tasty","id":17},"is_one_top":false,"slug":"mushroom-chicken-nuggets","draft_status":"published","total_time_minutes":null,"updated_at":1657230438,"seo_title":"","cook_time_minutes":10,"sections":[{"name":null,"position":1,"components":[{"id":95371,"position":1,"measurements":[{"unit":{"display_singular":"","abbreviation":"","system":"none","name":"","display_plural":""},"quantity":"0","id":696353}],"raw_text":"Vegetable oil, for frying","extra_comment":"","ingredient":{"updated_at":1654278453,"name":"Vegetable oil, for frying","created_at":1654278453,"display_plural":"Vegetable oil,s for frying","id":9813,"display_singular":"Vegetable oil, for frying"}},{"raw_text":"8 king trumpet mushrooms","extra_comment":"","ingredient":{"created_at":1657230293,"display_plural":"8 king trumpet mushrooms","id":9934,"display_singular":"8 king trumpet mushroom","updated_at":1657230293,"name":"8 king trumpet mushrooms"},"id":95372,"position":2,"measurements":[{"unit":{"system":"none","name":"","display_plural":"","display_singular":"","abbreviation":""},"quantity":"0","id":696351}]},{"raw_text":"⅓ cup buckwheat flour","extra_comment":"","ingredient":{"updated_at":1657230301,"name":"1/3 cup buckwheat flour","created_at":1657230301,"display_plural":"1/3 cup buckwheat flours","id":9935,"display_singular":"1/3 cup buckwheat flour"},"id":95373,"position":3,"measurements":[{"unit":{"display_plural":"","display_singular":"","abbreviation":"","system":"none","name":""},"quantity":"0","id":696355}]},{"raw_text":"⅓ cup cornstarch","extra_comment":"","ingredient":{"name":"1/3 cup cornstarch","created_at":1657230308,"display_plural":"1/3 cup cornstarches","id":9936,"display_singular":"1/3 cup cornstarch","updated_at":1657230308},"id":95374,"position":4,"measurements":[{"unit":{"system":"none","name":"","display_plural":"","display_singular":"","abbreviation":""},"quantity":"0","id":696361}]},{"raw_text":"½ teaspoon paprika","extra_comment":"","ingredient":{"display_plural":"1/2 teaspoon paprikas","id":9866,"display_singular":"1/2 teaspoon paprika","updated_at":1654796550,"name":"1/2 teaspoon paprika","created_at":1654796550},"id":95375,"position":5,"measurements":[{"unit":{"display_plural":"","display_singular":"","abbreviation":"","system":"none","name":""},"quantity":"0","id":696352}]},{"position":6,"measurements":[{"unit":{"system":"none","name":"","display_plural":"","display_singular":"","abbreviation":""},"quantity":"0","id":696360}],"raw_text":"½ teaspoon garlic powder","extra_comment":"","ingredient":{"updated_at":1652144091,"name":"1/2 teaspoon garlic powder","created_at":1652144091,"display_plural":"1/2 teaspoon garlic powders","id":9759,"display_singular":"1/2 teaspoon garlic powder"},"id":95376},{"extra_comment":"","ingredient":{"id":9939,"display_singular":"1 teaspoon kosher salt, plus more to taste","updated_at":1657230346,"name":"1 teaspoon kosher salt, plus more to taste","created_at":1657230346,"display_plural":"1 teaspoon kosher salt, plus mores to taste"},"id":95377,"position":7,"measurements":[{"unit":{"system":"none","name":"","display_plural":"","display_singular":"","abbreviation":""},"quantity":"0","id":696358}],"raw_text":"1 teaspo ...

# %%
response.json()
# Out:
# {'count': 27,
#  'results': [{'country': 'US',
#    'user_ratings': {'count_positive': 3, 'score': 0.375, 'count_negative': 5},
#    'compilations': [],
#    'tips_and_ratings_enabled': True,
#    'video_url': None,
#    'original_video_url': None,
#    'promotion': 'full',
#    'facebook_posts': [],
#    'id': 8354,
#    'description': 'These healthy-ish, plant-based mushroom nuggets will be the hype of your next get-together. This easy snack is crispy, crunchy, and savory and pairs well with almost any dipping sauce.',
#    'inspired_by_url': None,
#    'thumbnail_url': 'https://img.buzzfeed.com/tasty-app-user-assets-prod-us-east-1/recipes/49c3356ce3394ca9aec09bd7162a49b2.jpeg',
#    'topics': [{'slug': 'best-vegetarian', 'name': 'Best Vegetarian'},
#     {'name': 'Romantic Dinners', 'slug': 'romantic-dinners'},
#     {'slug': 'vegan', 'name': 'Vegan'},
#     {'name': 'Snacks', 'slug': 'snacks'}],
#    'num_servings': 4,
#    'show': {'name': 'Tasty', 'id': 17},
#    'is_one_top': False,
#    'slug': 'mushroom-chicken-nuggets',
#    'draft_status': 'published',
#    'total_time_minutes': None,
#    'updated_at': 1657230438,
#    'seo_title': '',
#    'cook_time_minutes': 10,
#    'sections': [{'name': None,
#      'position': 1,
#      'components': [{'id': 95371,
#        'position': 1,
#        'measurements': [{'unit': {'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': '',
#           'display_plural': ''},
#          'quantity': '0',
#          'id': 696353}],
#        'raw_text': 'Vegetable oil, for frying',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1654278453,
#         'name': 'Vegetable oil, for frying',
#         'created_at': 1654278453,
#         'display_plural': 'Vegetable oil,s for frying',
#         'id': 9813,
#         'display_singular': 'Vegetable oil, for frying'}},
#       {'raw_text': '8 king trumpet mushrooms',
#        'extra_comment': '',
#        'ingredient': {'created_at': 1657230293,
#         'display_plural': '8 king trumpet mushrooms',
#         'id': 9934,
#         'display_singular': '8 king trumpet mushroom',
#         'updated_at': 1657230293,
#         'name': '8 king trumpet mushrooms'},
#        'id': 95372,
#        'position': 2,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 696351}]},
#       {'raw_text': '⅓ cup buckwheat flour',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1657230301,
#         'name': '1/3 cup buckwheat flour',
#         'created_at': 1657230301,
#         'display_plural': '1/3 cup buckwheat flours',
#         'id': 9935,
#         'display_singular': '1/3 cup buckwheat flour'},
#        'id': 95373,
#        'position': 3,
#        'measurements': [{'unit': {'display_plural': '',
#           'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': ''},
#          'quantity': '0',
#          'id': 696355}]},
#       {'raw_text': '⅓ cup cornstarch',
#        'extra_comment': '',
#        'ingredient': {'name': '1/3 cup cornstarch',
#         'created_at': 1657230308,
#         'display_plural': '1/3 cup cornstarches',
#         'id': 9936,
#         'display_singular': '1/3 cup cornstarch',
#         'updated_at': 1657230308},
#        'id': 95374,
#        'position': 4,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 696361}]},
#       {'raw_text': '½ teaspoon paprika',
#        'extra_comment': '',
#        'ingredient': {'display_plural': '1/2 teaspoon paprikas',
#         'id': 9866,
#         'display_singular': '1/2 teaspoon paprika',
#         'updated_at': 1654796550,
#         'name': '1/2 teaspoon paprika',
#         'created_at': 1654796550},
#        'id': 95375,
#        'position': 5,
#        'measurements': [{'unit': {'display_plural': '',
#           'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': ''},
#          'quantity': '0',
#          'id': 696352}]},
#       {'position': 6,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 696360}],
#        'raw_text': '½ teaspoon garlic powder',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1652144091,
#         'name': '1/2 teaspoon garlic powder',
#         'created_at': 1652144091,
#         'display_plural': '1/2 teaspoon garlic powders',
#         'id': 9759,
#         'display_singular': '1/2 teaspoon garlic powder'},
#        'id': 95376},
#       {'extra_comment': '',
#        'ingredient': {'id': 9939,
#         'display_singular': '1 teaspoon kosher salt, plus more to taste',
#         'updated_at': 1657230346,
#         'name': '1 teaspoon kosher salt, plus more to taste',
#         'created_at': 1657230346,
#         'display_plural': '1 teaspoon kosher salt, plus mores to taste'},
#        'id': 95377,
#        'position': 7,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 696358}],
#        'raw_text': '1 teaspoon kosher salt, plus more to taste'},
#       {'measurements': [{'id': 696354,
#          'unit': {'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': '',
#           'display_plural': ''},
#          'quantity': '0'}],
#        'raw_text': '½ teaspoon freshly ground black pepper',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1654796622,
#         'name': '1/2 teaspoon freshly ground black pepper',
#         'created_at': 1654796622,
#         'display_plural': '1/2 teaspoon freshly ground black peppers',
#         'id': 9872,
#         'display_singular': '1/2 teaspoon freshly ground black pepper'},
#        'id': 95378,
#        'position': 8},
#       {'id': 95379,
#        'position': 9,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 696356}],
#        'raw_text': '½ cup water',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1657230363,
#         'name': '1/2 cup water',
#         'created_at': 1657230363,
#         'display_plural': '1/2 cup waters',
#         'id': 9941,
#         'display_singular': '1/2 cup water'}},
#       {'extra_comment': '',
#        'ingredient': {'id': 9942,
#         'display_singular': '1 1/2 teaspoon chili powder',
#         'updated_at': 1657230385,
#         'name': '1 1/2 teaspoon chili powder',
#         'created_at': 1657230385,
#         'display_plural': '1 1/2 teaspoon chili powders'},
#        'id': 95380,
#        'position': 10,
#        'measurements': [{'quantity': '0',
#          'id': 696350,
#          'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''}}],
#        'raw_text': '1½ teaspoons chili powder'},
#       {'ingredient': {'updated_at': 1657230393,
#         'name': '2 cups crushed cornflakes',
#         'created_at': 1657230393,
#         'display_plural': '2 cups crushed cornflakes',
#         'id': 9943,
#         'display_singular': '2 cups crushed cornflake'},
#        'id': 95381,
#        'position': 11,
#        'measurements': [{'id': 696359,
#          'unit': {'display_plural': '',
#           'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': ''},
#          'quantity': '0'}],
#        'raw_text': '2 cups crushed cornflakes',
#        'extra_comment': ''},
#       {'raw_text': 'Sauce of choice, for dipping',
#        'extra_comment': '',
#        'ingredient': {'display_singular': 'Sauce of choice, for dipping',
#         'updated_at': 1657230402,
#         'name': 'Sauce of choice, for dipping',
#         'created_at': 1657230402,
#         'display_plural': 'Sauces of choice, for dipping',
#         'id': 9944},
#        'id': 95382,
#        'position': 12,
#        'measurements': [{'quantity': '0',
#          'id': 696357,
#          'unit': {'display_plural': '',
#           'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': ''}}]}]}],
#    'brand_id': None,
#    'instructions': [{'start_time': 0,
#      'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72353,
#      'position': 1,
#      'display_text': 'Fill a large, high-walled skillet halfway with vegetable oil and heat over medium heat until the temperature reaches 350°F (180°C).'},
#     {'end_time': 0,
#      'temperature': None,
#      'id': 72354,
#      'position': 2,
#      'display_text': 'Remove the caps from the mushrooms and reserve for another use, then slice the mushroom stems into ½-inch-thick rounds.',
#      'start_time': 0,
#      'appliance': None},
#     {'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72355,
#      'position': 3,
#      'display_text': 'In a medium bowl, whisk together the buckwheat flour, cornstarch, paprika, garlic powder, salt, pepper. Add the water and whisk until smooth. Whisk in the chili powder.',
#      'start_time': 0},
#     {'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72356,
#      'position': 4,
#      'display_text': 'Add the cornflakes to a separate medium bowl',
#      'start_time': 0},
#     {'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72357,
#      'position': 5,
#      'display_text': 'Dip the mushroom rounds in the batter to coat completely, then dredge in the crushed cornflakes until fully covered.',
#      'start_time': 0},
#     {'end_time': 0,
#      'temperature': None,
#      'id': 72358,
#      'position': 6,
#      'display_text': 'Working in batches, fry the mushrooms in the hot oil until golden brown, 3–5 minutes per side. Transfer to a paper towel-lined plate to drain and sprinkle with salt.',
#      'start_time': 0,
#      'appliance': None},
#     {'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72359,
#      'position': 7,
#      'display_text': 'Serve warm with your favorite sauce for dipping.',
#      'start_time': 0},
#     {'start_time': 0,
#      'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 72360,
#      'position': 8,
#      'display_text': 'Enjoy!'}],
#    'keywords': '',
#    'language': 'eng',
#    'brand': None,
#    'servings_noun_singular': 'Servings',
#    'prep_time_minutes': 20,
#    'nutrition': {'carbohydrates': 0,
#     'fiber': 0,
#     'updated_at': '2022-08-16T08:01:50+02:00',
#     'protein': 0,
#     'fat': 6,
#     'calories': 59,
#     'sugar': 0},
#    'aspect_ratio': '16:9',
#    'yields': 'Servings: 4',
#    'is_shoppable': True,
#    'video_ad_content': None,
#    'tags': [{'name': 'easy',
#      'id': 64471,
#      'display_name': 'Easy',
#      'type': 'difficulty'},
#     {'name': 'under_1_hour',
#      'id': 8091748,
#      'display_name': 'Under 1 Hour',
#      'type': 'difficulty'},
#     {'name': 'dry_measuring_cups',
#      'id': 1280507,
#      'display_name': 'Dry Measuring Cups',
#      'type': 'equipment'},
#     {'name': 'vegan', 'id': 64468, 'display_name': 'Vegan', 'type': 'dietary'},
#     {'name': 'vegetarian',
#      'id': 64469,
#      'display_name': 'Vegetarian',
#      'type': 'dietary'},
#     {'name': 'whisk',
#      'id': 1247793,
#      'display_name': 'Whisk',
#      'type': 'equipment'},
#     {'name': 'snacks', 'id': 64491, 'display_name': 'Snacks', 'type': 'meal'},
#     {'name': 'tongs',
#      'id': 1247790,
#      'display_name': 'Tongs',
#      'type': 'equipment'},
#     {'display_name': 'Measuring Spoons',
#      'type': 'equipment',
#      'name': 'measuring_spoons',
#      'id': 1280508},
#     {'id': 64481,
#      'display_name': 'Appetizers',
#      'type': 'meal',
#      'name': 'appetizers'},
#     {'id': 65848,
#      'display_name': 'Stove Top',
#      'type': 'appliance',
#      'name': 'stove_top'},
#     {'type': 'equipment',
#      'name': 'mixing_bowl',
#      'id': 1280510,
#      'display_name': 'Mixing Bowl'},
#     {'type': 'equipment',
#      'name': 'spider',
#      'id': 1280514,
#      'display_name': 'Spider'},
#     {'name': 'under_30_minutes',
#      'id': 64472,
#      'display_name': 'Under 30 Minutes',
#      'type': 'difficulty'},
#     {'name': 'under_45_minutes',
#      'id': 8091747,
#      'display_name': 'Under 45 Minutes',
#      'type': 'difficulty'},
#     {'id': 64463,
#      'display_name': 'Dairy-Free',
#      'type': 'dietary',
#      'name': 'dairy_free'}],
#    'name': 'Mushroom “Chicken Nuggets”',
#    'buzz_id': None,
#    'created_at': 1657230228,
#    'approved_at': 1657230438,
#    'servings_noun_plural': 'Servings',
#    'video_id': None,
#    'nutrition_visibility': 'auto',
#    'total_time_tier': {'tier': 'under_30_minutes',
#     'display_tier': 'Under 30 minutes'},
#    'canonical_id': 'recipe:8354',
#    'show_id': 17,
#    'thumbnail_alt_text': '',
#    'credits': [{'name': 'Bella Lopez', 'type': 'internal'}],
#    'renditions': [],
#    'beauty_url': None},
#   {'brand': None,
#    'nutrition': {'fat': 37,
#     'calories': 890,
#     'sugar': 26,
#     'carbohydrates': 98,
#     'fiber': 4,
#     'updated_at': '2021-11-09T07:01:55+01:00',
#     'protein': 36},
#    'topics': [{'slug': 'fall', 'name': 'Fall Recipes'},
#     {'name': 'Romantic Dinners', 'slug': 'romantic-dinners'},
#     {'name': 'Thanksgiving', 'slug': 'thanksgiving'},
#     {'name': 'Lunch', 'slug': 'lunch'},
#     {'name': 'Dinner', 'slug': 'dinner'},
#     {'name': 'American', 'slug': 'american'}],
#    'canonical_id': 'recipe:7918',
#    'created_at': 1636075902,
#    'description': 'Transform your Thanksgiving leftovers into a hearty French dip-style sandwich. Cranberry sauce gets a remix with the addition of spicy stone-ground mustard, then it’s spread on a French roll and topped with thinly sliced turkey breast and Swiss cheese and broiled until melty. Serve with an aus jus made from leftover gravy that’s perfect for dipping!',
#    'video_url': 'https://vid.tasty.co/output/221881/hls24_1636075735.m3u8',
#    'beauty_url': None,
#    'seo_title': '',
#    'yields': 'Servings: 2',
#    'video_id': 145811,
#    'language': 'eng',
#    'id': 7918,
#    'slug': 'thanksgiving-turkey-french-dip',
#    'brand_id': None,
#    'num_servings': 2,
#    'tips_and_ratings_enabled': True,
#    'total_time_tier': {'tier': 'under_15_minutes',
#     'display_tier': 'Under 15 minutes'},
#    'sections': [{'components': [{'ingredient': {'display_singular': 'cranberry sauce',
#         'updated_at': 1509035185,
#         'name': 'cranberry sauce',
#         'created_at': 1496784192,
#         'display_plural': 'cranberry sauces',
#         'id': 1494},
#        'id': 89604,
#        'position': 2,
#        'measurements': [{'unit': {'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup'},
#          'quantity': '½',
#          'id': 668474},
#         {'unit': {'abbreviation': 'g',
#           'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g'},
#          'quantity': '165',
#          'id': 668472}],
#        'raw_text': '½ cup cranberry sauce',
#        'extra_comment': ''},
#       {'measurements': [{'unit': {'display_plural': 'tablespoons',
#           'display_singular': 'tablespoon',
#           'abbreviation': 'tbsp',
#           'system': 'imperial',
#           'name': 'tablespoon'},
#          'quantity': '3',
#          'id': 668471}],
#        'raw_text': '3 tablespoons stone-ground mustard',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035176,
#         'name': 'stone ground mustard',
#         'created_at': 1496933666,
#         'display_plural': 'stone ground mustards',
#         'id': 1632,
#         'display_singular': 'stone ground mustard'},
#        'id': 89605,
#        'position': 3}],
#      'name': 'Cranberry Mustard Sauce',
#      'position': 1},
#     {'position': 2,
#      'components': [{'raw_text': '1 cup gravy',
#        'extra_comment': '',
#        'ingredient': {'display_plural': 'gravies',
#         'id': 3265,
#         'display_singular': 'gravy',
#         'updated_at': 1511410225,
#         'name': 'gravy',
#         'created_at': 1511410225},
#        'id': 89607,
#        'position': 5,
#        'measurements': [{'unit': {'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup'},
#          'quantity': '1',
#          'id': 668480},
#         {'id': 668478,
#          'unit': {'display_singular': 'g',
#           'abbreviation': 'g',
#           'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g'},
#          'quantity': '240'}]},
#       {'extra_comment': '\n',
#        'ingredient': {'name': 'chicken stock',
#         'created_at': 1494124570,
#         'display_plural': 'chicken stocks',
#         'id': 196,
#         'display_singular': 'chicken stock',
#         'updated_at': 1509035280},
#        'id': 89608,
#        'position': 6,
#        'measurements': [{'quantity': '1',
#          'id': 668477,
#          'unit': {'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup'}},
#         {'unit': {'display_singular': 'mL',
#           'abbreviation': 'mL',
#           'system': 'metric',
#           'name': 'milliliter',
#           'display_plural': 'mL'},
#          'quantity': '240',
#          'id': 668476}],
#        'raw_text': '1 cup chicken stock'},
#       {'ingredient': {'updated_at': 1509035282,
#         'name': 'freshly ground black pepper',
#         'created_at': 1493925438,
#         'display_plural': 'freshly ground black peppers',
#         'id': 166,
#         'display_singular': 'freshly ground black pepper'},
#        'id': 89609,
#        'position': 7,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0',
#          'id': 668481}],
#        'raw_text': 'Freshly ground black pepper, to taste',
#        'extra_comment': 'to taste'}],
#      'name': 'Gravy Au Jus'},
#     {'position': 3,
#      'components': [{'ingredient': {'updated_at': 1558007871,
#         'name': 'French rolls',
#         'created_at': 1558007871,
#         'display_plural': 'French rolls',
#         'id': 5412,
#         'display_singular': 'French roll'},
#        'id': 89611,
#        'position': 9,
#        'measurements': [{'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '2',
#          'id': 668479}],
#        'raw_text': '2 French rolls, halved lengthwise',
#        'extra_comment': 'halved lengthwise'},
#       {'extra_comment': 'thinly sliced',
#        'ingredient': {'updated_at': 1511236316,
#         'name': 'turkey breast',
#         'created_at': 1511236316,
#         'display_plural': 'turkey breasts',
#         'id': 3251,
#         'display_singular': 'turkey breast'},
#        'id': 89612,
#        'position': 10,
#        'measurements': [{'id': 668475,
#          'unit': {'abbreviation': 'oz',
#           'system': 'imperial',
#           'name': 'ounce',
#           'display_plural': 'oz',
#           'display_singular': 'oz'},
#          'quantity': '6'},
#         {'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'},
#          'quantity': '175',
#          'id': 668473}],
#        'raw_text': '6–8 ounces turkey breast, thinly sliced'},
#       {'raw_text': '4–6 slices of Swiss cheese',
#        'extra_comment': '',
#        'ingredient': {'id': 1246,
#         'display_singular': 'swiss cheese',
#         'updated_at': 1509035199,
#         'name': 'swiss cheese',
#         'created_at': 1496594306,
#         'display_plural': 'swiss cheeses'},
#        'id': 89613,
#        'position': 11,
#        'measurements': [{'unit': {'display_plural': 'slices',
#           'display_singular': 'slice',
#           'abbreviation': 'slice',
#           'system': 'none',
#           'name': 'slice'},
#          'quantity': '4',
#          'id': 668470}]}],
#      'name': 'Assembly'}],
#    'thumbnail_url': 'https://img.buzzfeed.com/thumbnailer-prod-us-east-1/video-api/assets/351171.jpg',
#    'credits': [{'name': 'Tikeyah Whittle', 'type': 'internal'}],
#    'original_video_url': 'https://s3.amazonaws.com/video-api-prod/assets/6b0c51386d314549af6c2daf4b99175e/BFV84668_ThanksgivingFrenchDippedSandwich_JM_110421_v.04_1x1_YT_OO.mp4',
#    'show_id': 17,
#    'compilations': [],
#    'buzz_id': None,
#    'show': {'name': 'Tasty', 'id': 17},
#    'draft_status': 'published',
#    'prep_time_minutes': 5,
#    'name': 'Thanksgiving Turkey French Dip',
#    'inspired_by_url': None,
#    'thumbnail_alt_text': '',
#    'approved_at': 1636395354,
#    'is_one_top': False,
#    'servings_noun_plural': 'servings',
#    'facebook_posts': [],
#    'total_time_minutes': 10,
#    'updated_at': 1636395354,
#    'video_ad_content': 'none',
#    'cook_time_minutes': 2,
#    'aspect_ratio': '1:1',
#    'nutrition_visibility': 'auto',
#    'country': 'US',
#    'instructions': [{'position': 1,
#      'display_text': 'Make the cranberry mustard sauce: In a small bowl, mix together the cranberry sauce and mustard.',
#      'start_time': 5500,
#      'appliance': None,
#      'end_time': 14333,
#      'temperature': None,
#      'id': 69059},
#     {'temperature': None,
#      'id': 69060,
#      'position': 2,
#      'display_text': 'Make the gravy au jus: In a small saucepan, whisk together the gravy and chicken stock over medium heat until gently simmering. Season with black pepper as needed. Remove from the heat and divide between 2 small bowls for dipping.',
#      'start_time': 19500,
#      'appliance': None,
#      'end_time': 39816},
#     {'position': 3,
#      'display_text': 'Turn the broiler on high.',
#      'start_time': 0,
#      'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 69061},
#     {'appliance': None,
#      'end_time': 74000,
#      'temperature': None,
#      'id': 69062,
#      'position': 4,
#      'display_text': 'Place the bottom of each French roll, cut-side up, on a baking sheet. Spread about 2 tablespoons of cranberry mustard sauce on each half, then layer on the sliced turkey. Top with the Swiss cheese. Broil for 30 seconds.',
#      'start_time': 44000},
#     {'temperature': None,
#      'id': 69063,
#      'position': 5,
#      'display_text': 'Remove the pan from the oven and add the top buns, cut-side up. Broil for another 30 seconds, until the top buns are golden brown and the cheese is melted and lightly bubbling.',
#      'start_time': 0,
#      'appliance': None,
#      'end_time': 0},
#     {'appliance': None,
#      'end_time': 0,
#      'temperature': None,
#      'id': 69064,
#      'position': 6,
#      'display_text': 'Place the top buns on top of the melted cheese and transfer to plates with the au jus alongside for dipping. Serve immediately.',
#      'start_time': 0},
#     {'start_time': 82333,
#      'appliance': None,
#      'end_time': 89500,
#      'temperature': None,
#      'id': 69065,
#      'position': 7,
#      'display_text': 'Enjoy!'}],
#    'keywords': '',
#    'user_ratings': {'score': 1, 'count_negative': 0, 'count_positive': 7},
#    'servings_noun_singular': 'serving',
#    'tags': [{'display_name': 'Comfort Food',
#      'type': 'cooking_style',
#      'name': 'comfort_food',
#      'id': 64462},
#     {'type': 'equipment',
#      'name': 'whisk',
#      'id': 1247793,
#      'display_name': 'Whisk'},
#     {'type': 'appliance',
#      'name': 'stove_top',
#      'id': 65848,
#      'display_name': 'Stove Top'},
#     {'name': 'baking_pan',
#      'id': 1280500,
#      'display_name': 'Baking Pan',
#      'type': 'equipment'},
#     {'name': 'sauce_pan',
#      'id': 1247786,
#      'display_name': 'Sauce Pan',
#      'type': 'equipment'},
#     {'id': 1247788,
#      'display_name': 'Spatula',
#      'type': 'equipment',
#      'name': 'spatula'},
#     {'display_name': 'Thanksgiving',
#      'type': 'holiday',
#      'name': 'thanksgiving',
#      'id': 64479},
#     {'id': 1280501,
#      'display_name': "Chef's Knife",
#      'type': 'equipment',
#      'name': 'chefs_knife'},
#     {'name': 'dinner', 'id': 64486, 'display_name': 'Dinner', 'type': 'meal'},
#     {'display_name': 'Lunch', 'type': 'meal', 'name': 'lunch', 'id': 64489},
#     {'id': 64508, 'display_name': 'Fall', 'type': 'seasonal', 'name': 'fall'},
#     {'name': 'oven', 'id': 65846, 'display_name': 'Oven', 'type': 'appliance'},
#     {'display_name': 'American',
#      'type': 'cuisine',
#      'name': 'american',
#      'id': 64444},
#     {'name': 'special_occasion',
#      'id': 188967,
#      'display_name': 'Special Occasion',
#      'type': 'occasion'},
#     {'type': 'healthy',
#      'name': 'high_protein',
#      'id': 8091917,
#      'display_name': 'High-Protein'},
#     {'name': 'under_30_minutes',
#      'id': 64472,
#      'display_name': 'Under 30 Minutes',
#      'type': 'difficulty'},
#     {'name': 'under_15_minutes',
#      'id': 8091744,
#      'display_name': 'Under 15 Minutes',
#      'type': 'difficulty'},
#     {'name': 'under_45_minutes',
#      'id': 8091747,
#      'display_name': 'Under 45 Minutes',
#      'type': 'difficulty'},
#     {'display_name': 'Under 1 Hour',
#      'type': 'difficulty',
#      'name': 'under_1_hour',
#      'id': 8091748}],
#    'renditions': [{'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/221881/square_720/1636075735_00001.png',
#      'file_size': 21109443,
#      'url': 'https://vid.tasty.co/output/221881/square_720/1636075735',
#      'duration': 94761,
#      'bit_rate': 1783,
#      'width': 720,
#      'container': 'mp4',
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'name': 'mp4_720x720',
#      'maximum_bit_rate': None,
#      'height': 720,
#      'content_type': 'video/mp4'},
#     {'url': 'https://vid.tasty.co/output/221881/square_320/1636075735',
#      'width': 320,
#      'height': 320,
#      'container': 'mp4',
#      'file_size': 7527622,
#      'duration': 94761,
#      'bit_rate': 636,
#      'content_type': 'video/mp4',
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'name': 'mp4_320x320',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/221881/square_320/1636075735_00001.png',
#      'maximum_bit_rate': None},
#     {'url': 'https://vid.tasty.co/output/221881/landscape_720/1636075735',
#      'duration': 94761,
#      'aspect': 'square',
#      'width': 720,
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'container': 'mp4',
#      'file_size': 21110866,
#      'bit_rate': 1783,
#      'content_type': 'video/mp4',
#      'name': 'mp4_720x720',
#      'height': 720,
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/221881/landscape_720/1636075735_00001.png'},
#     {'bit_rate': 1048,
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'height': 480,
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/221881/landscape_480/1636075735_00001.png',
#      'url': 'https://vid.tasty.co/output/221881/landscape_480/1636075735',
#      'duration': 94761,
#      'content_type': 'video/mp4',
#      'width': 480,
#      'name': 'mp4_480x480',
#      'container': 'mp4',
#      'file_size': 12402330},
#     {'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/221881/1445289064805-h2exzu/1636075735_00001.png',
#      'url': 'https://vid.tasty.co/output/221881/hls24_1636075735.m3u8',
#      'content_type': 'application/vnd.apple.mpegurl',
#      'width': 1080,
#      'minimum_bit_rate': 274,
#      'maximum_bit_rate': 3004,
#      'height': 1080,
#      'container': 'ts',
#      'file_size': None,
#      'duration': 94762,
#      'bit_rate': None,
#      'aspect': 'square',
#      'name': 'low'}],
#    'is_shoppable': True,
#    'promotion': 'full'},
#   {'instructions': [{'temperature': None,
#      'id': 66498,
#      'position': 1,
#      'display_text': 'On a cutting board, slice the chicken breasts in half horizontally, creating 2 thin pieces. Place the chicken breasts, 1 at a time, in a large zip-top bag. Use a meat mallet to pound the chicken to ¼-inch-thick. Transfer the chicken to a cutting board and blot dry with a paper towel. Season the chicken on both sides with salt and pepper.',
#      'start_time': 7000,
#      'appliance': None,
#      'end_time': 35500},
#     {'start_time': 40000,
#      'appliance': None,
#      'end_time': 49833,
#      'temperature': None,
#      'id': 66499,
#      'position': 2,
#      'display_text': 'In a shallow bowl, whisk together the flour, 1 teaspoon salt, and 1 teaspoon pepper. In another shallow bowl, beat the eggs. Add the panko to a third shallow bowl.'},
#     {'start_time': 51000,
#      'appliance': None,
#      'end_time': 75166,
#      'temperature': None,
#      'id': 66500,
#      'position': 3,
#      'display_text': 'Coat the chicken in the flour, shaking off any excess. Then, dip in the eggs, letting any excess drip off. Finally, coat in the panko, making sure all sides are covered. Transfer the chicken to a clean cutting board.'},
#     {'temperature': None,
#      'id': 66501,
#      'position': 4,
#      'display_text': 'Heat the vegetable oil in a large pan over medium-high heat. Once the oil begins to shimmer, add the chicken and cook until golden brown, 2–3 minutes per side. Transfer the chicken to a paper towel-lined plate and season with salt. Serve the chicken schnitzel with lemon wedges and garnish with parsley.',
#      'start_time': 81000,
#      'appliance': None,
#      'end_time': 98333},
#     {'temperature': None,
#      'id': 66502,
#      'position': 5,
#      'display_text': 'Enjoy!',
#      'start_time': 109333,
#      'appliance': None,
#      'end_time': 114000}],
#    'servings_noun_singular': 'serving',
#    'approved_at': 1626965755,
#    'topics': [{'name': 'One-Pot Recipes', 'slug': 'one-pot'},
#     {'name': 'Romantic Dinners', 'slug': 'romantic-dinners'},
#     {'slug': 'lunch', 'name': 'Lunch'},
#     {'name': 'Dinner', 'slug': 'dinner'}],
#    'sections': [{'components': [{'raw_text': '1 pound boneless, skinless chicken breasts',
#        'extra_comment': '',
#        'ingredient': {'id': 6365,
#         'display_singular': 'boneless skinless chicken breast',
#         'updated_at': 1586561916,
#         'name': 'boneless skinless chicken breast',
#         'created_at': 1586561916,
#         'display_plural': 'boneless skinless chicken breasts'},
#        'id': 85740,
#        'position': 1,
#        'measurements': [{'unit': {'abbreviation': 'lb',
#           'system': 'imperial',
#           'name': 'pound',
#           'display_plural': 'lb',
#           'display_singular': 'lb'},
#          'quantity': '1',
#          'id': 650035},
#         {'unit': {'display_singular': 'g',
#           'abbreviation': 'g',
#           'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g'},
#          'quantity': '425',
#          'id': 650033}]},
#       {'raw_text': '1 teaspoon kosher salt, plus more to taste',
#        'extra_comment': 'plus more to taste',
#        'ingredient': {'updated_at': 1509035289,
#         'name': 'kosher salt',
#         'created_at': 1493307153,
#         'display_plural': 'kosher salts',
#         'id': 11,
#         'display_singular': 'kosher salt'},
#        'id': 85741,
#        'position': 2,
#        'measurements': [{'id': 650039,
#          'unit': {'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp',
#           'system': 'imperial',
#           'name': 'teaspoon'},
#          'quantity': '1'}]},
#       {'position': 3,
#        'measurements': [{'unit': {'system': 'imperial',
#           'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp'},
#          'quantity': '1',
#          'id': 650045}],
#        'raw_text': '1 teaspoon freshly ground black pepper, plus more to taste',
#        'extra_comment': 'plus more to taste',
#        'ingredient': {'display_plural': 'freshly ground black peppers',
#         'id': 166,
#         'display_singular': 'freshly ground black pepper',
#         'updated_at': 1509035282,
#         'name': 'freshly ground black pepper',
#         'created_at': 1493925438},
#        'id': 85742},
#       {'measurements': [{'unit': {'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c'},
#          'quantity': '1',
#          'id': 650036},
#         {'quantity': '125',
#          'id': 650032,
#          'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'}}],
#        'raw_text': '1 cup all-purpose flour',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1513187920,
#         'name': 'all purpose flour',
#         'created_at': 1513187920,
#         'display_plural': 'all purpose flours',
#         'id': 3393,
#         'display_singular': 'all purpose flour'},
#        'id': 85743,
#        'position': 4},
#       {'extra_comment': '',
#        'ingredient': {'updated_at': 1509035275,
#         'name': 'large egg',
#         'created_at': 1494382414,
#         'display_plural': 'large eggs',
#         'id': 253,
#         'display_singular': 'large egg'},
#        'id': 85744,
#        'position': 5,
#        'measurements': [{'unit': {'display_singular': '',
#           'abbreviation': '',
#           'system': 'none',
#           'name': '',
#           'display_plural': ''},
#          'quantity': '2',
#          'id': 650040}],
#        'raw_text': '2 large eggs'},
#       {'extra_comment': '',
#        'ingredient': {'updated_at': 1509035280,
#         'name': 'panko breadcrumbs',
#         'created_at': 1494124470,
#         'display_plural': 'panko breadcrumbs',
#         'id': 195,
#         'display_singular': 'panko breadcrumb'},
#        'id': 85745,
#        'position': 6,
#        'measurements': [{'id': 650037,
#          'unit': {'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c'},
#          'quantity': '1 ½'},
#         {'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'},
#          'quantity': '170',
#          'id': 650034}],
#        'raw_text': '1½ cups panko bread crumbs'},
#       {'raw_text': '¼ cup vegetable oil',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035288,
#         'name': 'vegetable oil',
#         'created_at': 1493314628,
#         'display_plural': 'vegetable oils',
#         'id': 20,
#         'display_singular': 'vegetable oil'},
#        'id': 85746,
#        'position': 7,
#        'measurements': [{'unit': {'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c',
#           'system': 'imperial'},
#          'quantity': '¼',
#          'id': 650041},
#         {'unit': {'display_singular': 'mL',
#           'abbreviation': 'mL',
#           'system': 'metric',
#           'name': 'milliliter',
#           'display_plural': 'mL'},
#          'quantity': '60',
#          'id': 650038}]},
#       {'measurements': [{'id': 650042,
#          'unit': {'system': 'none',
#           'name': '',
#           'display_plural': '',
#           'display_singular': '',
#           'abbreviation': ''},
#          'quantity': '0'}],
#        'raw_text': 'Lemon wedges, for serving',
#        'extra_comment': 'for serving',
#        'ingredient': {'display_plural': 'lemon wedges',
#         'id': 4072,
#         'display_singular': 'lemon wedge',
#         'updated_at': 1526070227,
#         'name': 'lemon wedges',
#         'created_at': 1526070227},
#        'id': 85747,
#        'position': 8},
#       {'ingredient': {'display_singular': 'fresh parsley',
#         'updated_at': 1509035283,
#         'name': 'fresh parsley',
#         'created_at': 1493906396,
#         'display_plural': 'fresh parsleys',
#         'id': 154},
#        'id': 85748,
#        'position': 9,
#        'measurements': [{'unit': {'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c'},
#          'quantity': '¼',
#          'id': 650044},
#         {'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'},
#          'quantity': '10',
#          'id': 650043}],
#        'raw_text': '¼ cup finely chopped fresh parsley, for serving',
#        'extra_comment': ''}],
#      'name': None,
#      'position': 1}],
#    'brand_id': None,
#    'thumbnail_url': 'https://img.buzzfeed.com/thumbnailer-prod-us-east-1/video-api/assets/331839.jpg',
#    'thumbnail_alt_text': '',
#    'user_ratings': {'count_positive': 86,
#     'score': 0.977273,
#     'count_negative': 2},
#    'id': 7625,
#    'show_id': 17,
#    'prep_time_minutes': 20,
#    'video_ad_content': 'none',
#    'canonical_id': 'recipe:7625',
#    'total_time_minutes': 26,
#    'video_url': 'https://vid.tasty.co/output/209363/hls24_1626216175.m3u8',
#    'updated_at': 1626965755,
#    'credits': [{'name': None, 'type': 'internal'}],
#    'nutrition_visibility': 'auto',
#    'is_shoppable': True,
#    'nutrition': {'carbohydrates': 46,
#     'fiber': 1,
#     'updated_at': '2021-07-15T08:09:19+02:00',
#     'protein': 37,
#     'fat': 25,
#     'calories': 563,
#     'sugar': 1},
#    'renditions': [{'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/209363/square_720/1626216175_00001.png',
#      'url': 'https://vid.tasty.co/output/209363/square_720/1626216175',
#      'bit_rate': 2117,
#      'aspect': 'square',
#      'width': 720,
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'container': 'mp4',
#      'file_size': 31004330,
#      'duration': 117167,
#      'content_type': 'video/mp4',
#      'name': 'mp4_720x720',
#      'height': 720},
#     {'file_size': 10290972,
#      'url': 'https://vid.tasty.co/output/209363/square_320/1626216175',
#      'duration': 117167,
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'height': 320,
#      'maximum_bit_rate': None,
#      'container': 'mp4',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/209363/square_320/1626216175_00001.png',
#      'bit_rate': 703,
#      'content_type': 'video/mp4',
#      'width': 320,
#      'name': 'mp4_320x320'},
#     {'file_size': 30997206,
#      'duration': 117167,
#      'width': 720,
#      'name': 'mp4_720x720',
#      'height': 720,
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/209363/landscape_720/1626216175_00001.png',
#      'url': 'https://vid.tasty.co/output/209363/landscape_720/1626216175',
#      'bit_rate': 2117,
#      'content_type': 'video/mp4',
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'container': 'mp4'},
#     {'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/209363/landscape_480/1626216175_00001.png',
#      'file_size': 17783081,
#      'url': 'https://vid.tasty.co/output/209363/landscape_480/1626216175',
#      'duration': 117167,
#      'bit_rate': 1215,
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'container': 'mp4',
#      'content_type': 'video/mp4',
#      'width': 480,
#      'name': 'mp4_480x480',
#      'maximum_bit_rate': None,
#      'height': 480},
#     {'content_type': 'application/vnd.apple.mpegurl',
#      'width': 1080,
#      'maximum_bit_rate': 3592,
#      'container': 'ts',
#      'url': 'https://vid.tasty.co/output/209363/hls24_1626216175.m3u8',
#      'duration': 117159,
#      'aspect': 'square',
#      'minimum_bit_rate': 274,
#      'name': 'low',
#      'height': 1080,
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/209363/1445289064805-h2exzu/1626216175_00001.png',
#      'file_size': None,
#      'bit_rate': None}],
#    'promotion': 'full',
#    'brand': None,
#    'inspired_by_url': None,
#    'cook_time_minutes': 6,
#    'tips_and_ratings_enabled': True,
#    'aspect_ratio': '1:1',
#    'is_one_top': False,
#    'yields': 'Servings: 4',
#    'country': 'US',
#    'keywords': '',
#    'name': 'Chicken Schnitzel',
#    'buzz_id': None,
#    'created_at': 1626216307,
#    'description': 'Crispy chicken for everyone! Our version of schnitzel is pan-fried to golden brown perfection and finished with a squeeze of lemon and shower of parsley for brightness. Serve alongside your favorite side dishes, sliced atop a salad, or between bread for a crispy chicken sandwich.',
#    'original_video_url': 'https://s3.amazonaws.com/video-api-prod/assets/d6986e37e8df424d80cac9bb3e85aa5e/BFV788800_50TastyCoVideosQF_ChickenSchnitzel_EG_06302021_v04_1x1_IG.mp4',
#    'video_id': 128538,
#    'facebook_posts': [],
#    'slug': 'chicken-schnitzel',
#    'compilations': [],
#    'show': {'name': 'Tasty', 'id': 17},
#    'servings_noun_plural': 'servings',
#    'beauty_url': None,
#    'total_time_tier': {'tier': 'under_30_minutes',
#     'display_tier': 'Under 30 minutes'},
#    'seo_title': 'Chicken Schnitzel Recipe by Tasty',
#    'language': 'eng',
#    'tags': [{'type': 'appliance',
#      'name': 'stove_top',
#      'id': 65848,
#      'display_name': 'Stove Top'},
#     {'display_name': 'Dry Measuring Cups',
#      'type': 'equipment',
#      'name': 'dry_measuring_cups',
#      'id': 1280507},
#     {'name': 'measuring_spoons',
#      'id': 1280508,
#      'display_name': 'Measuring Spoons',
#      'type': 'equipment'},
#     {'type': 'equipment',
#      'name': 'cutting_board',
#      'id': 1280503,
#      'display_name': 'Cutting Board'},
#     {'name': 'german',
#      'id': 64450,
#      'display_name': 'German',
#      'type': 'cuisine'},
#     {'name': 'liquid_measuring_cup',
#      'id': 1280506,
#      'display_name': 'Liquid Measuring Cup',
#      'type': 'equipment'},
#     {'name': 'one_pot_or_pan',
#      'id': 65855,
#      'display_name': 'One-Pot or Pan',
#      'type': 'cooking_style'},
#     {'display_name': 'Comfort Food',
#      'type': 'cooking_style',
#      'name': 'comfort_food',
#      'id': 64462},
#     {'name': 'saute_pan',
#      'id': 1247787,
#      'display_name': 'Saute Pan',
#      'type': 'equipment'},
#     {'name': 'dinner', 'id': 64486, 'display_name': 'Dinner', 'type': 'meal'},
#     {'id': 1247793,
#      'display_name': 'Whisk',
#      'type': 'equipment',
#      'name': 'whisk'},
#     {'name': 'lunch', 'id': 64489, 'display_name': 'Lunch', 'type': 'meal'},
#     {'name': 'weeknight',
#      'id': 64505,
#      'display_name': 'Weeknight',
#      'type': 'occasion'},
#     {'type': 'cooking_style',
#      'name': 'deep_fry',
#      'id': 64493,
#      'display_name': 'Deep-Fry'},
#     {'name': 'mixing_bowl',
#      'id': 1280510,
#      'display_name': 'Mixing Bowl',
#      'type': 'equipment'},
#     {'name': 'high_protein',
#      'id': 8091917,
#      'display_name': 'High-Protein',
#      'type': 'healthy'},
#     {'name': 'low_sugar',
#      'id': 8091918,
#      'display_name': 'Low-Sugar',
#      'type': 'healthy'},
#     {'name': 'under_30_minutes',
#      'id': 64472,
#      'display_name': 'Under 30 Minutes',
#      'type': 'difficulty'},
#     {'type': 'difficulty',
#      'name': 'under_45_minutes',
#      'id': 8091747,
#      'display_name': 'Under 45 Minutes'},
#     {'name': 'under_1_hour',
#      'id': 8091748,
#      'display_name': 'Under 1 Hour',
#      'type': 'difficulty'},
#     {'name': 'dairy_free',
#      'id': 64463,
#      'display_name': 'Dairy-Free',
#      'type': 'dietary'}],
#    'num_servings': 4,
#    'draft_status': 'published'},
#   {'draft_status': 'published',
#    'video_ad_content': 'none',
#    'country': 'US',
#    'compilations': [],
#    'aspect_ratio': '1:1',
#    'original_video_url': 'https://s3.amazonaws.com/video-api-prod/assets/9f1b038cc3954248920fe729872930c4/BFV78805_50TastyCoVideosQF_BasicSkilletChickenBreasts_EG_06302021_v04_1x1_IG.mp4',
#    'instructions': [{'start_time': 6000,
#      'appliance': None,
#      'end_time': 15500,
#      'temperature': None,
#      'id': 66405,
#      'position': 1,
#      'display_text': 'On a cutting board, pat the chicken breasts dry with paper towels. Season all over with the salt and pepper.'},
#     {'display_text': 'Heat the grapeseed oil in a large skillet over medium-high heat. Once the oil begins to shimmer, add the chicken breasts and cook, without moving, until golden brown, 8–10 minutes. Carefully flip the chicken over and continue cooking, without moving, until the other side is golden brown and the internal temperature reaches 165°F (75°C), 8–10 minutes more.',
#      'start_time': 20000,
#      'appliance': None,
#      'end_time': 35666,
#      'temperature': None,
#      'id': 66406,
#      'position': 2},
#     {'appliance': None,
#      'end_time': 47666,
#      'temperature': None,
#      'id': 66407,
#      'position': 3,
#      'display_text': 'Transfer the chicken to a cutting board and let rest for 5 minutes before slicing.',
#      'start_time': 40000},
#     {'start_time': 50000,
#      'appliance': None,
#      'end_time': 55500,
#      'temperature': None,
#      'id': 66408,
#      'position': 4,
#      'display_text': 'Enjoy!'}],
#    'is_shoppable': True,
#    'seo_title': 'Skillet Chicken Breast Recipe by Tasty',
#    'name': 'Skillet Chicken Breasts',
#    'renditions': [{'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/208990/square_720/1625860040_00001.png',
#      'bit_rate': 1774,
#      'width': 720,
#      'name': 'mp4_720x720',
#      'maximum_bit_rate': None,
#      'container': 'mp4',
#      'file_size': 12984107,
#      'url': 'https://vid.tasty.co/output/208990/square_720/1625860040',
#      'duration': 58561,
#      'content_type': 'video/mp4',
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'height': 720},
#     {'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/208990/square_320/1625860040_00001.png',
#      'file_size': 4484743,
#      'url': 'https://vid.tasty.co/output/208990/square_320/1625860040',
#      'duration': 58561,
#      'bit_rate': 613,
#      'content_type': 'video/mp4',
#      'width': 320,
#      'container': 'mp4',
#      'maximum_bit_rate': None,
#      'minimum_bit_rate': None,
#      'name': 'mp4_320x320',
#      'height': 320,
#      'aspect': 'square'},
#     {'aspect': 'square',
#      'width': 720,
#      'minimum_bit_rate': None,
#      'name': 'mp4_720x720',
#      'container': 'mp4',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/208990/landscape_720/1625860040_00001.png',
#      'file_size': 12976343,
#      'content_type': 'video/mp4',
#      'maximum_bit_rate': None,
#      'height': 720,
#      'url': 'https://vid.tasty.co/output/208990/landscape_720/1625860040',
#      'duration': 58561,
#      'bit_rate': 1773},
#     {'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/208990/landscape_480/1625860040_00001.png',
#      'bit_rate': 1033,
#      'content_type': 'video/mp4',
#      'width': 480,
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'height': 480,
#      'container': 'mp4',
#      'url': 'https://vid.tasty.co/output/208990/landscape_480/1625860040',
#      'duration': 58561,
#      'aspect': 'square',
#      'name': 'mp4_480x480',
#      'file_size': 7561058},
#     {'height': 1080,
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/208990/1445289064805-h2exzu/1625860040_00001.png',
#      'file_size': None,
#      'url': 'https://vid.tasty.co/output/208990/hls24_1625860040.m3u8',
#      'duration': 58560,
#      'width': 1080,
#      'maximum_bit_rate': 2997,
#      'container': 'ts',
#      'bit_rate': None,
#      'content_type': 'application/vnd.apple.mpegurl',
#      'aspect': 'square',
#      'minimum_bit_rate': 270,
#      'name': 'low'}],
#    'topics': [{'name': '5 Ingredients or Less',
#      'slug': '5-ingredients-or-less'},
#     {'name': 'Easy Dinner', 'slug': 'easy-dinner'},
#     {'name': 'One-Pot Recipes', 'slug': 'one-pot'},
#     {'name': 'Romantic Dinners', 'slug': 'romantic-dinners'},
#     {'name': 'Lunch', 'slug': 'lunch'},
#     {'name': 'Dinner', 'slug': 'dinner'},
#     {'name': 'American', 'slug': 'american'}],
#    'video_id': 128544,
#    'language': 'eng',
#    'user_ratings': {'count_positive': 56,
#     'score': 0.933333,
#     'count_negative': 4},
#    'show_id': 17,
# ...
#        'extra_comment': 'cut into 2-inch (5 cm) pieces',
#        'ingredient': {'updated_at': 1509035286,
#         'name': 'chicken breast',
#         'created_at': 1493430237,
#         'display_plural': 'chicken breasts',
#         'id': 50,
#         'display_singular': 'chicken breast'},
#        'id': 65857,
#        'position': 2,
#        'measurements': [{'id': 555343,
#          'unit': {'display_singular': 'lb',
#           'abbreviation': 'lb',
#           'system': 'imperial',
#           'name': 'pound',
#           'display_plural': 'lb'},
#          'quantity': '1 ½'},
#         {'quantity': '670',
#          'id': 555342,
#          'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'}}]},
#       {'raw_text': '2 teaspoons kosher salt, divided',
#        'extra_comment': 'divided',
#        'ingredient': {'updated_at': 1509035289,
#         'name': 'kosher salt',
#         'created_at': 1493307153,
#         'display_plural': 'kosher salts',
#         'id': 11,
#         'display_singular': 'kosher salt'},
#        'id': 65858,
#        'position': 3,
#        'measurements': [{'quantity': '2',
#          'id': 555344,
#          'unit': {'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp',
#           'system': 'imperial'}}]},
#       {'raw_text': '1 teaspoon freshly ground black pepper, divided',
#        'extra_comment': 'divided',
#        'ingredient': {'updated_at': 1509035282,
#         'name': 'freshly ground black pepper',
#         'created_at': 1493925438,
#         'display_plural': 'freshly ground black peppers',
#         'id': 166,
#         'display_singular': 'freshly ground black pepper'},
#        'id': 65859,
#        'position': 4,
#        'measurements': [{'unit': {'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp',
#           'system': 'imperial'},
#          'quantity': '1',
#          'id': 555339}]},
#       {'id': 65860,
#        'position': 5,
#        'measurements': [{'unit': {'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup'},
#          'quantity': '2',
#          'id': 555349},
#         {'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'},
#          'quantity': '250',
#          'id': 555347}],
#        'raw_text': '2 cups dry pancake mix',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1582073606,
#         'name': 'dry pancake mix',
#         'created_at': 1582073606,
#         'display_plural': 'dry pancake mixes',
#         'id': 6179,
#         'display_singular': 'dry pancake mix'}},
#       {'id': 65861,
#        'position': 6,
#        'measurements': [{'unit': {'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp',
#           'system': 'imperial'},
#          'quantity': '⅛',
#          'id': 555345}],
#        'raw_text': '⅛ teaspoon cayenne',
#        'extra_comment': '',
#        'ingredient': {'id': 2786,
#         'display_singular': 'cayenne',
#         'updated_at': 1509035109,
#         'name': 'cayenne',
#         'created_at': 1501634171,
#         'display_plural': 'cayennes'}},
#       {'id': 65862,
#        'position': 7,
#        'measurements': [{'unit': {'system': 'imperial',
#           'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp'},
#          'quantity': '1',
#          'id': 555346}],
#        'raw_text': '1 teaspoon paprika',
#        'extra_comment': '',
#        'ingredient': {'display_singular': 'paprika',
#         'updated_at': 1509035286,
#         'name': 'paprika',
#         'created_at': 1493430149,
#         'display_plural': 'paprikas',
#         'id': 42}},
#       {'ingredient': {'display_plural': 'garlic powders',
#         'id': 9,
#         'display_singular': 'garlic powder',
#         'updated_at': 1509035289,
#         'name': 'garlic powder',
#         'created_at': 1493307128},
#        'id': 65863,
#        'position': 8,
#        'measurements': [{'unit': {'abbreviation': 'tsp',
#           'system': 'imperial',
#           'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon'},
#          'quantity': '1',
#          'id': 555350}],
#        'raw_text': '1 teaspoon garlic powder',
#        'extra_comment': ''},
#       {'position': 9,
#        'measurements': [{'unit': {'display_singular': 'cup',
#           'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups'},
#          'quantity': '1',
#          'id': 555338},
#         {'unit': {'system': 'metric',
#           'name': 'milliliter',
#           'display_plural': 'mL',
#           'display_singular': 'mL',
#           'abbreviation': 'mL'},
#          'quantity': '240',
#          'id': 555337}],
#        'raw_text': '1 cup buttermilk',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035239,
#         'name': 'buttermilk',
#         'created_at': 1495666444,
#         'display_plural': 'buttermilks',
#         'id': 701,
#         'display_singular': 'buttermilk'},
#        'id': 65864},
#       {'id': 65865,
#        'position': 10,
#        'measurements': [{'id': 555341,
#          'unit': {'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c'},
#          'quantity': '½'},
#         {'unit': {'system': 'metric',
#           'name': 'milliliter',
#           'display_plural': 'mL',
#           'display_singular': 'mL',
#           'abbreviation': 'mL'},
#          'quantity': '120',
#          'id': 555340}],
#        'raw_text': '½ cup water',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035280,
#         'name': 'water',
#         'created_at': 1494124627,
#         'display_plural': 'waters',
#         'id': 197,
#         'display_singular': 'water'}},
#       {'position': 11,
#        'measurements': [{'unit': {'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup'},
#          'quantity': '4',
#          'id': 555336},
#         {'unit': {'abbreviation': 'mL',
#           'system': 'metric',
#           'name': 'milliliter',
#           'display_plural': 'mL',
#           'display_singular': 'mL'},
#          'quantity': '960',
#          'id': 555334}],
#        'raw_text': '4 cups vegetable oil, for frying',
#        'extra_comment': 'for frying',
#        'ingredient': {'updated_at': 1509035288,
#         'name': 'vegetable oil',
#         'created_at': 1493314628,
#         'display_plural': 'vegetable oils',
#         'id': 20,
#         'display_singular': 'vegetable oil'},
#        'id': 65866}],
#      'name': 'Fried Chicken',
#      'position': 1},
#     {'components': [{'position': 13,
#        'measurements': [{'quantity': '1',
#          'id': 555335,
#          'unit': {'system': 'imperial',
#           'name': 'cup',
#           'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c'}},
#         {'unit': {'display_singular': 'g',
#           'abbreviation': 'g',
#           'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g'},
#          'quantity': '250',
#          'id': 555333}],
#        'raw_text': '1 cup Dijon mustard',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035271,
#         'name': 'dijon mustard',
#         'created_at': 1494812213,
#         'display_plural': 'dijon mustards',
#         'id': 307,
#         'display_singular': 'dijon mustard'},
#        'id': 65868},
#       {'extra_comment': '',
#        'ingredient': {'id': 359,
#         'display_singular': 'maple syrup',
#         'updated_at': 1509035267,
#         'name': 'maple syrup',
#         'created_at': 1494966352,
#         'display_plural': 'maple syrups'},
#        'id': 65869,
#        'position': 14,
#        'measurements': [{'id': 555332,
#          'unit': {'display_plural': 'cups',
#           'display_singular': 'cup',
#           'abbreviation': 'c',
#           'system': 'imperial',
#           'name': 'cup'},
#          'quantity': '¾'},
#         {'unit': {'system': 'metric',
#           'name': 'gram',
#           'display_plural': 'g',
#           'display_singular': 'g',
#           'abbreviation': 'g'},
#          'quantity': '250',
#          'id': 555330}],
#        'raw_text': '¾ cup pancake syrup'},
#       {'position': 15,
#        'measurements': [{'unit': {'system': 'imperial',
#           'name': 'tablespoon',
#           'display_plural': 'tablespoons',
#           'display_singular': 'tablespoon',
#           'abbreviation': 'tbsp'},
#          'quantity': '2',
#          'id': 555331}],
#        'raw_text': '2 tablespoons vegetable oil',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035288,
#         'name': 'vegetable oil',
#         'created_at': 1493314628,
#         'display_plural': 'vegetable oils',
#         'id': 20,
#         'display_singular': 'vegetable oil'},
#        'id': 65870},
#       {'id': 65871,
#        'position': 16,
#        'measurements': [{'unit': {'system': 'imperial',
#           'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp'},
#          'quantity': '½',
#          'id': 555351}],
#        'raw_text': '½ teaspoon kosher salt',
#        'extra_comment': '',
#        'ingredient': {'id': 11,
#         'display_singular': 'kosher salt',
#         'updated_at': 1509035289,
#         'name': 'kosher salt',
#         'created_at': 1493307153,
#         'display_plural': 'kosher salts'}},
#       {'raw_text': '½ teaspoon black pepper',
#        'extra_comment': '',
#        'ingredient': {'updated_at': 1509035289,
#         'name': 'black pepper',
#         'created_at': 1493307183,
#         'display_plural': 'black peppers',
#         'id': 12,
#         'display_singular': 'black pepper'},
#        'id': 65872,
#        'position': 17,
#        'measurements': [{'id': 555348,
#          'unit': {'system': 'imperial',
#           'name': 'teaspoon',
#           'display_plural': 'teaspoons',
#           'display_singular': 'teaspoon',
#           'abbreviation': 'tsp'},
#          'quantity': '½'}]}],
#      'name': 'Mustard Dipping Sauce',
#      'position': 2}],
#    'nutrition': {},
#    'approved_at': 1582753493,
#    'yields': 'Servings: 4-6',
#    'country': 'US',
#    'id': 6043,
#    'video_url': 'https://vid.tasty.co/output/160117/hls24_1581465962.m3u8',
#    'credits': [{'name': 'Betsy Carter', 'type': 'internal'},
#     {'name': 'Nicholas Torres', 'type': 'internal'}],
#    'servings_noun_plural': 'servings',
#    'seo_title': 'Pancake Battered Chicken Nuggets',
#    'original_video_url': 'https://s3.amazonaws.com/video-api-prod/assets/ddcbf9656e77440ab41cab6576b7da96/BFV64112_PancakeBatteredChicken_AE_021120_V002_OO.mp4',
#    'cook_time_minutes': 20,
#    'language': 'eng',
#    'slug': 'pancake-batter-fried-chicken',
#    'buzz_id': None,
#    'description': 'Move over, chicken and waffles--there’s a new mashup in town. Coat the chicken in a spicy pancake batter and fry them to crispy golden brown. It’s a crowd-pleasing appetizer that comes together in 30 minutes!',
#    'thumbnail_alt_text': '',
#    'promotion': 'full',
#    'video_id': 100510,
#    'user_ratings': {'count_positive': 357,
#     'score': 0.917738,
#     'count_negative': 32},
#    'tips_and_ratings_enabled': True,
#    'created_at': 1582135260,
#    'inspired_by_url': None,
#    'is_one_top': False,
#    'prep_time_minutes': 5,
#    'show_id': 17,
#    'tags': [{'type': 'equipment',
#      'name': 'mixing_bowl',
#      'id': 1280510,
#      'display_name': 'Mixing Bowl'},
#     {'name': 'tongs',
#      'id': 1247790,
#      'display_name': 'Tongs',
#      'type': 'equipment'},
#     {'name': 'whisk',
#      'id': 1247793,
#      'display_name': 'Whisk',
#      'type': 'equipment'},
#     {'id': 64486, 'display_name': 'Dinner', 'type': 'meal', 'name': 'dinner'},
#     {'name': 'brunch',
#      'id': 64484,
#      'display_name': 'Brunch',
#      'type': 'occasion'},
#     {'display_name': 'Oven', 'type': 'appliance', 'name': 'oven', 'id': 65846},
#     {'name': 'under_30_minutes',
#      'id': 64472,
#      'display_name': 'Under 30 Minutes',
#      'type': 'difficulty'},
#     {'name': 'under_45_minutes',
#      'id': 8091747,
#      'display_name': 'Under 45 Minutes',
#      'type': 'difficulty'},
#     {'id': 8091748,
#      'display_name': 'Under 1 Hour',
#      'type': 'difficulty',
#      'name': 'under_1_hour'}],
#    'aspect_ratio': '1:1',
#    'show': {'name': 'Tasty', 'id': 17},
#    'draft_status': 'published',
#    'updated_at': 1582753491,
#    'renditions': [{'maximum_bit_rate': None,
#      'height': 720,
#      'url': 'https://vid.tasty.co/output/160117/square_720/1581465962',
#      'duration': 71286,
#      'aspect': 'square',
#      'minimum_bit_rate': None,
#      'content_type': 'video/mp4',
#      'width': 720,
#      'name': 'mp4_720x720',
#      'container': 'mp4',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/160117/square_720/1581465962_00001.png',
#      'file_size': 25347635,
#      'bit_rate': 2845},
#     {'name': 'mp4_320x320',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/160117/square_320/1581465962_00001.png',
#      'file_size': 8475670,
#      'url': 'https://vid.tasty.co/output/160117/square_320/1581465962',
#      'content_type': 'video/mp4',
#      'aspect': 'square',
#      'width': 320,
#      'minimum_bit_rate': None,
#      'height': 320,
#      'container': 'mp4',
#      'duration': 71286,
#      'bit_rate': 952,
#      'maximum_bit_rate': None},
#     {'bit_rate': 2845,
#      'content_type': 'video/mp4',
#      'minimum_bit_rate': None,
#      'maximum_bit_rate': None,
#      'width': 720,
#      'name': 'mp4_720x720',
#      'container': 'mp4',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/160117/landscape_720/1581465962_00001.png',
#      'file_size': 25346853,
#      'url': 'https://vid.tasty.co/output/160117/landscape_720/1581465962',
#      'duration': 71286,
#      'aspect': 'square',
#      'height': 720},
#     {'width': 480,
#      'minimum_bit_rate': None,
#      'name': 'mp4_480x480',
#      'maximum_bit_rate': None,
#      'file_size': 14601054,
#      'aspect': 'square',
#      'url': 'https://vid.tasty.co/output/160117/landscape_480/1581465962',
#      'duration': 71286,
#      'bit_rate': 1639,
#      'content_type': 'video/mp4',
#      'height': 480,
#      'container': 'mp4',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/160117/landscape_480/1581465962_00001.png'},
#     {'bit_rate': None,
#      'aspect': 'square',
#      'width': 1080,
#      'name': 'low',
#      'height': 1080,
#      'url': 'https://vid.tasty.co/output/160117/hls24_1581465962.m3u8',
#      'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/160117/1445289064805-h2exzu/1581465962_00001.png',
#      'file_size': None,
#      'duration': 71280,
#      'content_type': 'application/vnd.apple.mpegurl',
#      'minimum_bit_rate': 274,
#      'maximum_bit_rate': 4846,
#      'container': 'ts'}],
#    'brand': None,
#    'topics': [{'name': 'Sunday Brunch', 'slug': 'brunch'},
#     {'slug': 'romantic-dinners', 'name': 'Romantic Dinners'},
#     {'name': 'Dinner', 'slug': 'dinner'}],
#    'num_servings': 4,
#    'thumbnail_url': 'https://img.buzzfeed.com/thumbnailer-prod-us-east-1/video-api/assets/255004.jpg',
#    'video_ad_content': 'none',
#    'nutrition_visibility': 'auto',
#    'servings_noun_singular': 'serving ',
#    'total_time_minutes': 30,
#    'beauty_url': None,
#    'canonical_id': 'recipe:6043',
#    'keywords': 'brunch ideas, chicken and waffles, chicken nugget recipes, easy to share recipes, finger foods, fun recipes for kids, fun ways to fry chicken, pancake battered chicken, remixed chicken recipe, tasty, tastysinglerecipe'}]}
